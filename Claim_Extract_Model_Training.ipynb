# %%
# !pip install -U transformers trl peft accelerate bitsandbytes datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 104.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 697.4/697.4 kB 65.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.7/680.7 kB 67.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 45.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 52.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 55.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
# ...

# %%
# !python train_qwen_module1_sft_colab.py \
  --train-file module1_sft_1000.json \
  --model-name Qwen/Qwen2.5-7B-Instruct \
  --output-dir qwen-module1-lora
# Out:
# ...
# config.json: 100% 663/663 [00:00<00:00, 3.19MB/s]
# tokenizer_config.json: 7.30kB [00:00, 20.7MB/s]
# vocab.json: 2.78MB [00:00, 53.0MB/s]
# merges.txt: 1.67MB [00:00, 109MB/s]
# tokenizer.json: 7.03MB [00:00, 142MB/s]
# model.safetensors.index.json: 27.8kB [00:00, 75.4MB/s]
# ...
# Fetching 4 files: 100% 4/4 [00:38<00:00,  9.71s/it]
# Download complete: 100% 15.2G/15.2G [00:38<00:00, 392MB/s]
# Loading weights: 100% 339/339 [00:04<00:00, 79.92it/s]
# generation_config.json: 100% 243/243 [00:00<00:00, 1.29MB/s]
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Adding EOS to train dataset: 100% 1000/1000 [00:00<00:00, 28589.47 examples/s]
# Tokenizing train dataset: 100% 1000/1000 [00:00<00:00, 1071.62 examples/s]
# ...

# %%
# !zip -r qwen-module1-lora.zip qwen-module1-lora
from google.colab import files
files.download("qwen-module1-lora.zip")
# Out:
#   adding: qwen-module1-lora/ (stored 0%)
#   adding: qwen-module1-lora/checkpoint-250/ (stored 0%)
#   adding: qwen-module1-lora/checkpoint-250/trainer_state.json (deflated 74%)
#   adding: qwen-module1-lora/checkpoint-250/scheduler.pt (deflated 62%)
#   adding: qwen-module1-lora/checkpoint-250/optimizer.pt (deflated 11%)
#   adding: qwen-module1-lora/checkpoint-250/training_args.bin (deflated 53%)
#   adding: qwen-module1-lora/checkpoint-250/README.md (deflated 65%)
#   adding: qwen-module1-lora/checkpoint-250/tokenizer.json (deflated 81%)
#   adding: qwen-module1-lora/checkpoint-250/chat_template.jinja (deflated 71%)
#   adding: qwen-module1-lora/checkpoint-250/tokenizer_config.json (deflated 59%)
#   adding: qwen-module1-lora/checkpoint-250/adapter_model.safetensors (deflated 21%)
#   adding: qwen-module1-lora/checkpoint-250/adapter_config.json (deflated 59%)
#   adding: qwen-module1-lora/checkpoint-250/rng_state.pth (deflated 26%)
# ...
